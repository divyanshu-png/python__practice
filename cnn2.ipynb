# %%
print("Hello world")
# Out:
# Hello world

# %%
#global variable
name='Divyanshu'
def return_name(name): 
    return name #local variable

return_name(name)
# Out:
# 'Divyanshu'

# %% [markdown]
# I am Divyanshu Singh. This is area to write notes

# %%
print(-(3+1-8*54+99))
88**9
2000%2
2001//2
# Out:
# 1000

# %%
print("hola \t(tabspace) new freind\nnew line")
# Out:
# hola 	(tabspace) new freind
# new line

# %%
0.2+0.1-0.3
# Out:
# 5.551115123125783e-17

# %%
1/2
# Out:
# 0.5

# %%
type(name)
# Out:
# str

# %%
my_income=10000
taxrate=0.05 #5% income tax rate
my_income=my_income-(taxrate*my_income)
print(my_income)
# Out:
# 9500.0

# %%
mystring='abcdefghijkl'
print(mystring[5])
print(mystring[:6])
print(mystring[::2])
print(mystring)
# Out:
# f
# abcdef
# acegik
# abcdefghijkl

# %%
mystring[4]='d'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mystring[4]='d'
#
# TypeError: 'str' object does not support item assignment

# %%
2+'3'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 2+'3'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
w="Hello World"
w.find("o") #returns the index of the first letter of the first instance of the substring
print(w.capitalize())
print(w.upper())
print(w)
# Out:
# Hello world
# HELLO WORLD
# Hello World

# %%
y= "HI this is a String"
y.split()
# Out:
# ['HI', 'this', 'is', 'a', 'String']

# %%
#string interpolation
print(w+". Today is a nice day ")
# Out:
# Hello World. Today is a nice day

# %%
inp= "a3"
inp.strip("")
inp[0] 
inp[1]
# Out:
# '3'

# %%
s = input("Enter the position").strip()
print(s)
# Out:
# a3
