# %% [markdown]
# #@title CSV files
#
# csv stands for Comma seperated variables and is a very common output for spreadsheet programs.
#
# while its possible to export excel files and Google Spreadsheets to .csv files, it only exports the information.
#
# Simply put, a .csv file only contains the raw data from the spreadsheet
#
# # csv module for Python, we will allow us to to grab columns, rows and values from a .csv file as well as write to a .csv file
#
#
# # Can also use pandas(mostly data science applications),
# # Openpyxl(Supports Excel Formulas, retains a lot of Excel Specific functionality, python-excel.org tracks various other Excel based Python Libraries.),
# # Google Sheets Python API (Direct python interface for working with Google Spreadsheets, Allow you to directly makes changes to the spreadsheets hosted online, More complex syntax but available in many programming languages)
