# %%
pwd
# Out:
# 'd:\\New folder (3)\\PYTHON'

# %%
f=open('practice.txt','w+')
f.write("this is a test string ")
f.close()

# %%
import os
os.getcwd()
# Out:
# 'd:\\New folder (3)\\PYTHON'

# %%
os.listdir()
# Out:
# ['.git',
#  '.vscode',
#  'chess_coloring.py',
#  'cnn.py',
#  'cnn2.ipynb',
#  'mymain_package',
#  'mymodule.py',
#  'myprogram.py',
#  'My_Book.txt',
#  'one.py',
#  'practice.txt',
#  'pylint_testing.py',
#  'shutil_and_OS_module.ipynb',
#  'two.py',
#  '__pycache__']

# %%
os.listdir(r'd:\New folder (3)')
# Out:
# ['4.0 File Paths',
#  'Advanced_java',
#  'HTML',
#  'mymodule.py',
#  'PYTHON',
#  'WEBDEVELOPMENTBOOTCAMP']

# %%
import shutil

# %%
shutil.move(src='practice.txt', dst=r'd:\New folder (3)\PYTHON\mymain_package\sub_package')
# Out:
# 'd:\\New folder (3)\\PYTHON\\mymain_package\\sub_package\\practice.txt'

# %%
os.listdir(r'd:\New folder (3)\PYTHON')
# Out:
# ['.git',
#  '.vscode',
#  'chess_coloring.py',
#  'cnn.py',
#  'cnn2.ipynb',
#  'mymain_package',
#  'mymodule.py',
#  'myprogram.py',
#  'My_Book.txt',
#  'one.py',
#  'pylint_testing.py',
#  'shutil_and_OS_module.ipynb',
#  'two.py',
#  '__pycache__']

# %%
pip install send2trash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import send2trash 
os.listdir()
# Out:
# ['.git',
#  '.vscode',
#  'chess_coloring.py',
#  'cnn.py',
#  'cnn2.ipynb',
#  'image.png',
#  'mymain_package',
#  'mymodule.py',
#  'myprogram.py',
#  'My_Book.txt',
#  'one.py',
#  'pylint_testing.py',
#  'shutil_and_OS_module.ipynb',
#  'two.py',
#  '__pycache__']

# %%
shutil.move(r'D:\New folder (3)\PYTHON\mymain_package\sub_package\practice.txt', os.getcwd())
# Out:
# 'd:\\New folder (3)\\PYTHON\\practice.txt'

# %%
os.listdir()
# Out:
# ['.git',
#  '.vscode',
#  'chess_coloring.py',
#  'cnn.py',
#  'cnn2.ipynb',
#  'image.png',
#  'mymain_package',
#  'mymodule.py',
#  'myprogram.py',
#  'My_Book.txt',
#  'one.py',
#  'practice.txt',
#  'pylint_testing.py',
#  'shutil_and_OS_module.ipynb',
#  'two.py',
#  '__pycache__']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.git',
#  '.vscode',
#  'chess_coloring.py',
#  'cnn.py',
#  'cnn2.ipynb',
#  'image.png',
#  'mymain_package',
#  'mymodule.py',
#  'myprogram.py',
#  'My_Book.txt',
#  'one.py',
#  'pylint_testing.py',
#  'shutil_and_OS_module.ipynb',
#  'two.py',
#  '__pycache__']

# %%
for folder, subfolders, files in os.walk(os.getcwd()):
    print(f"Currently looking at {folder} \n")
    print('The subfolders are :')
    for sub_fold in subfolders:
        print(f"Subfolder: {sub_fold}")
    print('\n')
    for f in files:
        print(f"\t File: {f}")
    print('\n')
# Out:
# Currently looking at d:\New folder (3)\PYTHON
#
# The subfolders are :
# Subfolder: .git
# Subfolder: .vscode
# Subfolder: mymain_package
# Subfolder: __pycache__
#
#
# 	 File: chess_coloring.py
# 	 File: cnn.py
# 	 File: cnn2.ipynb
# 	 File: image.png
# 	 File: mymodule.py
# 	 File: myprogram.py
# 	 File: My_Book.txt
# 	 File: one.py
# 	 File: pylint_testing.py
# 	 File: shutil_and_OS_module.ipynb
# 	 File: two.py
#
#
# Currently looking at d:\New folder (3)\PYTHON\.git
#
# The subfolders are :
# Subfolder: hooks
# Subfolder: info
# Subfolder: logs
# Subfolder: objects
# Subfolder: refs
#
#
# 	 File: COMMIT_EDITMSG
# 	 File: config
# 	 File: description
# 	 File: FETCH_HEAD
# 	 File: HEAD
# 	 File: index
#
#
# Currently looking at d:\New folder (3)\PYTHON\.git\hooks
#
# The subfolders are :
#
#
# 	 File: applypatch-msg.sample
# 	 File: commit-msg.sample
# 	 File: fsmonitor-watchman.sample
# 	 File: post-update.sample
# 	 File: pre-applypatch.sample
# 	 File: pre-commit.sample
# ...

# %%
for folder, subfolders, files in os.walk(r'D:\New folder (3)\PYTHON\mymain_package'):
    print(f"Currently looking at {folder} \n")
    print('The subfolders are :')
    for sub_fold in subfolders:
        print(f"Subfolder: {sub_fold}")
    print('\n')
    for f in files:
        print(f"\t File: {f}")
    print('\n')
# Out:
# Currently looking at D:\New folder (3)\PYTHON\mymain_package
#
# The subfolders are :
# Subfolder: sub_package
# Subfolder: __pycache__
#
#
# 	 File: cap.py
# 	 File: mysuperscrip.py
# 	 File: test_cap.py
# 	 File: __init__.py
#
#
# Currently looking at D:\New folder (3)\PYTHON\mymain_package\sub_package
#
# The subfolders are :
# Subfolder: __pycache__
#
#
# 	 File: mysubscrip.py
# 	 File: __init__.py
#
#
# Currently looking at D:\New folder (3)\PYTHON\mymain_package\sub_package\__pycache__
#
# The subfolders are :
#
#
# 	 File: mysubscrip.cpython-313.pyc
# 	 File: __init__.cpython-313.pyc
#
#
# Currently looking at D:\New folder (3)\PYTHON\mymain_package\__pycache__
#
# The subfolders are :
#
#
# 	 File: cap.cpython-313.pyc
# 	 File: mymain_package.cpython-313.pyc
# 	 File: mysuperscrip.cpython-313.pyc
# 	 File: __init__.cpython-313.pyc

# %%
os.walk(r"D:\New folder (3)\PYTHON\mymain_package")
# Out:
# <generator object walk at 0x000001D619A34EA0>
