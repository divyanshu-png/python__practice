# %% [markdown]
# <a href="https://colab.research.google.com/github/divyanshu-png/python__practice/blob/main/tictactoe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def player_input_choice():
  player1_symbol_choice="Wrong"
  while player1_symbol_choice.lower() not in ['x','o']:
    player1_symbol_choice=input("Player 1 ; Please pick a Marker X or O: " )
    if player1_symbol_choice=='X':
      player2_symbl_choice='O'
    elif player1_symbol_choice=='O':
      player2_symbl_choice='X'
    else:
      print("Wrong Input! Try again")
  return player1_symbol_choice, player2_symbl_choice

# %%
from IPython.display import clear_output
board=[1,2,3,4,5,6,7,8,9]
def display_board(board):
  board_game= list(board[i:i+3] for i in range(0,len(board),3))
  print(board_game)
display_board(board)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import random
def choose_first():
  #randomly choosing which player's turn it is
  flip=random.randint(0,1)
  if flip==0:
    return 'Player 1'
  else:
    return "Player 2"
#=usage: turn= choose_first()

# %%
def space_check(board, position):
  if board[position] in ['X','O']:
    return False
  else:
    return True

# %%
def full_board_check(board):
  for i in range(0,10):
    if space_check(board,i):
      return False
  return True

# %%
def player_input_position(board,symbol_choice):
  choice="Wrong"
  while choice not in board:
    choice=int(input(f"Enter the position you want to enter {symbol_choice}: "))
    if choice not in board:
      print("Please enter a valid number: ")
  return choice

# %%
def replay():
  choice=input("Play again? y/n")
  return choice.lower()=='y'

# %%
def Play():
  while True:
    player_1, player_2=player_input_choice()
     player_input_position()



    if not replay():
      break
